# %%
import numpy as np
import pandas as pd
import time
from yahoo_fin import stock_info as si
import matplotlib.pyplot as plt
import seaborn as sns
import random
sns.set()

# %%
import pkg_resources
import types


def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            name = val.__name__.split('.')[0]
        elif isinstance(val, type):
            name = val.__module__.split('.')[0]
        poorly_named_packages = {'PIL': 'Pillow', 'sklearn': 'scikit-learn'}
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]
        yield name


imports = list(set(get_imports()))
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name != 'pip':
        requirements.append((m.project_name, m.version))

for r in requirements:
    print('{}=={}'.format(*r))
# Out:
# seaborn==0.11.2
# pandas==1.2.2
# numpy==1.20.3
# matplotlib==3.4.2

# %%
def load_data(ticker, n_steps=50, scale=True, shuffle=True, lookup_step=1, split_by_date=True,
                test_size=0.2, feature_columns=['date', 'open', 'high', 'low','close','adjclose', 'volume']):
    """
    Loads data from Yahoo Finance source, as well as scaling, shuffling, normalizing and splitting.
    Params:
        ticker (str/pd.DataFrame): the ticker you want to load, examples include AAPL, TESL, etc.
        n_steps (int): the historical sequence length (i.e window size) used to predict, default is 50
        scale (bool): whether to scale prices from 0 to 1, default is True
        shuffle (bool): whether to shuffle the dataset (both training & testing), default is True
        lookup_step (int): the future lookup step to predict, default is 1 (e.g next day)
        split_by_date (bool): whether we split the dataset into training/testing by date, setting it 
            to False will split datasets in a random way
            test_size (float): ratio for test data, default is 0.2 (20% testing data)
        feature_columns (list): the list of features to use to feed into the model, default is everything grabbed from yahoo_fin
    """
    # see if ticker is already a loaded stock from yahoo finance
    if isinstance(ticker, str):
        # load it from yahoo_fin library
        df = si.get_data(ticker)
    elif isinstance(ticker, pd.DataFrame):
        # already loaded, use it directly
        df = ticker
    else:
        raise TypeError("ticker can be either a str or a `pd.DataFrame` instances")
    return df

df=load_data('TSLA')
df
# Out:
#                   open        high         low       close    adjclose  \
# 2010-06-29    3.800000    5.000000    3.508000    4.778000    4.778000
# 2010-06-30    5.158000    6.084000    4.660000    4.766000    4.766000
# 2010-07-01    5.000000    5.184000    4.054000    4.392000    4.392000
# 2010-07-02    4.600000    4.620000    3.742000    3.840000    3.840000
# 2010-07-06    4.000000    4.000000    3.166000    3.222000    3.222000
# ...                ...         ...         ...         ...         ...
# 2021-09-10  759.599976  762.609985  734.520020  736.270020  736.270020
# 2021-09-13  740.210022  744.780029  708.849976  743.000000  743.000000
# 2021-09-14  742.570007  754.469971  736.400024  744.489990  744.489990
# 2021-09-15  745.000000  756.859985  738.359985  755.830017  755.830017
# 2021-09-16  752.830017  756.799988  747.609985  756.150024  756.150024
#
#               volume ticker
# 2010-06-29  93831500   TSLA
# 2010-06-30  85935500   TSLA
# 2010-07-01  41094000   TSLA
# 2010-07-02  25699000   TSLA
# 2010-07-06  34334500   TSLA
# ...              ...    ...
# 2021-09-10  15114300   TSLA
# 2021-09-13  22952500   TSLA
# 2021-09-14  18524900   TSLA
# 2021-09-15  15331400   TSLA
# 2021-09-16  10069463   TSLA
#
# [2825 rows x 7 columns]

# %%
class Deep_Evolution_Strategy:
    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-7)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')


class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        return decision

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:
    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, window_size, trend, skip, initial_money):
        self.model = model
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.es = (
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision = self.model.predict(np.array(sequence))
        return np.argmax(decision[0])
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        self.model.weights = weights
        state = self.get_state(0)
        inventory = []
        quantity = 0
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                starting_money -= close[t]
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                starting_money += self.trend[t]

            state = next_state
        return ((starting_money - initial_money) / initial_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        state = self.get_state(0)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            state = next_state

        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

# %%
close = df.close.values.tolist()
window_size = 30
skip = 1
initial_money = 10000

model = Model(input_size = window_size, layer_size = 500, output_size = 3)
agent = Agent(model = model, 
              window_size = window_size,
              trend = close,
              skip = skip,
              initial_money = initial_money)
agent
model
#agent.fit(iterations = 500, checkpoint = 10)

# %%
states_buy, states_sell, total_gains, invest = agent.buy()
# states_sell  = agent.get_state(12)
# states_sell
# Out:
# day 12: buy 1 unit at price 4.128000, total balance 9995.872000
# day 13: buy 1 unit at price 4.382000, total balance 9991.490000
# day 14, sell 1 unit at price 4.060000, investment -1.647283 %, total balance 9995.550000,
# day 17, sell 1 unit at price 4.258000, investment -2.829760 %, total balance 9999.808000,
# day 27: buy 1 unit at price 3.918000, total balance 9995.890000
# day 28, sell 1 unit at price 3.920000, investment 0.051049 %, total balance 9999.810000,
# day 31: buy 1 unit at price 3.520000, total balance 9996.290000
# day 33, sell 1 unit at price 3.756000, investment 6.704547 %, total balance 10000.046000,
# day 36: buy 1 unit at price 3.758000, total balance 9996.288000
# day 37, sell 1 unit at price 3.820000, investment 1.649815 %, total balance 10000.108000,
# day 57: buy 1 unit at price 4.212000, total balance 9995.896000
# day 58, sell 1 unit at price 4.154000, investment -1.377020 %, total balance 10000.050000,
# day 66: buy 1 unit at price 4.120000, total balance 9995.930000
# day 67, sell 1 unit at price 4.198000, investment 1.893206 %, total balance 10000.128000,
# day 83: buy 1 unit at price 4.272000, total balance 9995.856000
# day 84, sell 1 unit at price 4.200000, investment -1.685394 %, total balance 10000.056000,
# day 94: buy 1 unit at price 5.872000, total balance 9994.184000
# day 95, sell 1 unit at price 5.608000, investment -4.495920 %, total balance 9999.792000,
# day 104: buy 1 unit at price 7.094000, total balance 9992.698000
# day 105: buy 1 unit at price 7.064000, total balance 9985.634000
# day 106, sell 1 unit at price 6.866000, investment -3.213979 %, total balance 9992.500000,
# day 107, sell 1 unit at price 7.066000, investment 0.028311 %, total balance 9999.566000,
# day 115: buy 1 unit at price 6.304000, total balance 9993.262000
# day 118, sell 1 unit at price 5.920000, investment -6.091368 %, total balance 9999.182000,
# day 120: buy 1 unit at price 6.272000, total balance 9992.910000
# day 121, sell 1 unit at price 6.340000, investment 1.084189 %, total balance 9999.250000,
# day 123: buy 1 unit at price 6.526000, total balance 9992.724000
# day 124, sell 1 unit at price 6.018000, investment -7.784246 %, total balance 9998.742001,
# day 133: buy 1 unit at price 5.576000, total balance 9993.166000
# day 134: buy 1 unit at price 5.648000, total balance 9987.518001
# day 135, sell 1 unit at price 5.690000, investment 2.044473 %, total balance 9993.208001,
# day 136, sell 1 unit at price 5.392000, investment -4.532570 %, total balance 9998.600001,
# day 141: buy 1 unit at price 4.806000, total balance 9993.794001
# day 142: buy 1 unit at price 4.524000, total balance 9989.270000
# day 143, sell 1 unit at price 4.608000, investment -4.119859 %, total balance 9993.878000,
# day 144, sell 1 unit at price 4.898000, investment 8.267011 %, total balance 9998.776000,
# day 149: buy 1 unit at price 4.820000, total balance 9993.956000
# day 150, sell 1 unit at price 4.782000, investment -0.788384 %, total balance 9998.738000,
# day 152: buy 1 unit at price 4.726000, total balance 9994.012000
# day 154, sell 1 unit at price 4.614000, investment -2.369869 %, total balance 9998.626000,
# day 163: buy 1 unit at price 4.636000, total balance 9993.990000
# day 164, sell 1 unit at price 4.374000, investment -5.651425 %, total balance 9998.364000,
# day 165: buy 1 unit at price 4.366000, total balance 9993.998000
# day 166: buy 1 unit at price 4.506000, total balance 9989.492000
# day 167, sell 1 unit at price 4.722000, investment 8.153915 %, total balance 9994.214000,
# day 168, sell 1 unit at price 4.778000, investment 6.036392 %, total balance 9998.992000,
# day 187: buy 1 unit at price 4.550000, total balance 9994.441999
# day 188, sell 1 unit at price 4.650000, investment 2.197800 %, total balance 9999.092000,
# day 193: buy 1 unit at price 5.166000, total balance 9993.926000
# day 194, sell 1 unit at price 5.340000, investment 3.368182 %, total balance 9999.266000,
# day 210: buy 1 unit at price 5.532000, total balance 9993.734000
# day 212: buy 1 unit at price 5.490000, total balance 9988.244000
# day 213, sell 1 unit at price 5.374000, investment -2.856110 %, total balance 9993.618000,
# day 215, sell 1 unit at price 5.288000, investment -3.679411 %, total balance 9998.906000,
# day 217: buy 1 unit at price 5.582000, total balance 9993.324000
# day 218, sell 1 unit at price 5.666000, investment 1.504839 %, total balance 9998.990000,
# day 220: buy 1 unit at price 5.534000, total balance 9993.456000
# day 221, sell 1 unit at price 5.510000, investment -0.433677 %, total balance 9998.966001,
# day 228: buy 1 unit at price 5.344000, total balance 9993.622001
# day 229, sell 1 unit at price 5.796000, investment 8.458087 %, total balance 9999.418001,
# day 237: buy 1 unit at price 5.674000, total balance 9993.744001
# day 238, sell 1 unit at price 5.424000, investment -4.406063 %, total balance 9999.168001,
# day 246: buy 1 unit at price 5.202000, total balance 9993.966001
# day 247, sell 1 unit at price 5.506000, investment 5.843904 %, total balance 9999.472001,
# day 251: buy 1 unit at price 5.492000, total balance 9993.980000
# day 252, sell 1 unit at price 5.622000, investment 2.367081 %, total balance 9999.602001,
# day 287: buy 1 unit at price 5.166000, total balance 9994.436001
# day 288: buy 1 unit at price 4.852000, total balance 9989.584001
# day 289, sell 1 unit at price 4.460000, investment -13.666277 %, total balance 9994.044001,
# day 291, sell 1 unit at price 4.592000, investment -5.358619 %, total balance 9998.636001,
# day 295: buy 1 unit at price 4.942000, total balance 9993.694001
# day 296, sell 1 unit at price 4.926000, investment -0.323751 %, total balance 9998.620001,
# day 306: buy 1 unit at price 4.868000, total balance 9993.752001
# day 307, sell 1 unit at price 4.964000, investment 1.972066 %, total balance 9998.716001,
# day 326: buy 1 unit at price 5.560000, total balance 9993.156001
# day 329, sell 1 unit at price 5.484000, investment -1.366902 %, total balance 9998.640001,
# day 341: buy 1 unit at price 5.742000, total balance 9992.898001
# day 342, sell 1 unit at price 6.492000, investment 13.061651 %, total balance 9999.390001,
# day 344: buy 1 unit at price 6.254000, total balance 9993.136001
# day 345: buy 1 unit at price 6.368000, total balance 9986.768001
# day 346, sell 1 unit at price 6.176000, investment -1.247203 %, total balance 9992.944001,
# day 348, sell 1 unit at price 6.728000, investment 5.653268 %, total balance 9999.672001,
# day 353: buy 1 unit at price 6.520000, total balance 9993.152001
# day 354, sell 1 unit at price 6.352000, investment -2.576683 %, total balance 9999.504002,
# day 356: buy 1 unit at price 6.290000, total balance 9993.214002
# day 358, sell 1 unit at price 6.512000, investment 3.529414 %, total balance 9999.726002,
# day 362: buy 1 unit at price 6.660000, total balance 9993.066002
# day 363: buy 1 unit at price 6.884000, total balance 9986.182002
# day 364, sell 1 unit at price 6.974000, investment 4.714717 %, total balance 9993.156002,
# day 365, sell 1 unit at price 6.838000, investment -0.668216 %, total balance 9999.994002,
# day 383: buy 1 unit at price 5.542000, total balance 9994.452002
# day 385, sell 1 unit at price 5.382000, investment -2.887042 %, total balance 9999.834002,
# day 391: buy 1 unit at price 5.320000, total balance 9994.514002
# day 392, sell 1 unit at price 5.362000, investment 0.789470 %, total balance 9999.876002,
# day 396: buy 1 unit at price 5.484000, total balance 9994.392002
# day 397, sell 1 unit at price 5.594000, investment 2.005829 %, total balance 9999.986001,
# day 399: buy 1 unit at price 5.866000, total balance 9994.120001
# day 400, sell 1 unit at price 5.914000, investment 0.818272 %, total balance 10000.034001,
# day 414: buy 1 unit at price 6.994000, total balance 9993.040001
# day 415, sell 1 unit at price 6.900000, investment -1.344007 %, total balance 9999.940001,
# day 419: buy 1 unit at price 6.724000, total balance 9993.216002
# day 420, sell 1 unit at price 6.762000, investment 0.565141 %, total balance 9999.978002,
# day 425: buy 1 unit at price 6.622000, total balance 9993.356001
# day 427, sell 1 unit at price 6.614000, investment -0.120815 %, total balance 9999.970001,
# day 433: buy 1 unit at price 7.064000, total balance 9992.906001
# day 434: buy 1 unit at price 6.996000, total balance 9985.910001
# day 435, sell 1 unit at price 6.992000, investment -1.019253 %, total balance 9992.902001,
# day 438, sell 1 unit at price 6.816000, investment -2.572896 %, total balance 9999.718001,
# day 447: buy 1 unit at price 6.896000, total balance 9992.822001
# day 450, sell 1 unit at price 6.618000, investment -4.031321 %, total balance 9999.440001,
# day 459: buy 1 unit at price 6.364000, total balance 9993.076002
# day 460, sell 1 unit at price 6.582000, investment 3.425518 %, total balance 9999.658001,
# day 462: buy 1 unit at price 6.668000, total balance 9992.990001
# day 463, sell 1 unit at price 6.626000, investment -0.629878 %, total balance 9999.616001,
# day 471: buy 1 unit at price 6.592000, total balance 9993.024001
# day 472, sell 1 unit at price 6.450000, investment -2.154129 %, total balance 9999.474001,
# day 475: buy 1 unit at price 5.836000, total balance 9993.638001
# day 476: buy 1 unit at price 5.714000, total balance 9987.924001
# day 477, sell 1 unit at price 5.512000, investment -5.551746 %, total balance 9993.436001,
# day 478, sell 1 unit at price 5.754000, investment 0.700034 %, total balance 9999.190001,
# day 482: buy 1 unit at price 5.962000, total balance 9993.228001
# day 483: buy 1 unit at price 6.338000, total balance 9986.890001
# day 484, sell 1 unit at price 6.082000, investment 2.012746 %, total balance 9992.972001,
# day 487, sell 1 unit at price 5.576000, investment -12.022714 %, total balance 9998.548001,
# day 491: buy 1 unit at price 6.016000, total balance 9992.532001
# day 492, sell 1 unit at price 5.824000, investment -3.191488 %, total balance 9998.356001,
# day 494: buy 1 unit at price 5.954000, total balance 9992.402001
# day 495, sell 1 unit at price 5.878000, investment -1.276456 %, total balance 9998.280001,
# day 497: buy 1 unit at price 6.368000, total balance 9991.912001
# day 498, sell 1 unit at price 6.418000, investment 0.785179 %, total balance 9998.330001,
# day 501: buy 1 unit at price 6.758000, total balance 9991.572001
# day 502, sell 1 unit at price 6.622000, investment -2.012425 %, total balance 9998.194002,
# day 509: buy 1 unit at price 6.246000, total balance 9991.948002
# day 510, sell 1 unit at price 6.198000, investment -0.768490 %, total balance 9998.146002,
# day 512: buy 1 unit at price 6.254000, total balance 9991.892002
# day 513: buy 1 unit at price 6.302000, total balance 9985.590002
# day 515, sell 1 unit at price 6.850000, investment 9.529896 %, total balance 9992.440001,
# day 516, sell 1 unit at price 7.192000, investment 14.122499 %, total balance 9999.632001,
# day 519: buy 1 unit at price 6.454000, total balance 9993.178001
# day 521, sell 1 unit at price 6.132000, investment -4.989154 %, total balance 9999.310001,
# day 527: buy 1 unit at price 5.484000, total balance 9993.826001
# day 528, sell 1 unit at price 5.250000, investment -4.266962 %, total balance 9999.076001,
# day 530: buy 1 unit at price 5.454000, total balance 9993.622001
# day 531, sell 1 unit at price 5.654000, investment 3.667030 %, total balance 9999.276001,
# day 534: buy 1 unit at price 5.882000, total balance 9993.394001
# day 535: buy 1 unit at price 5.988000, total balance 9987.406001
# day 536, sell 1 unit at price 6.234000, investment 5.984363 %, total balance 9993.640001,
# day 537, sell 1 unit at price 5.884000, investment -1.736809 %, total balance 9999.524001,
# day 546: buy 1 unit at price 5.664000, total balance 9993.860001
# day 547, sell 1 unit at price 5.738000, investment 1.306495 %, total balance 9999.598001,
# day 551: buy 1 unit at price 5.628000, total balance 9993.970001
# day 552, sell 1 unit at price 5.588000, investment -0.710731 %, total balance 9999.558001,
# day 553: buy 1 unit at price 5.710000, total balance 9993.848001
# day 554, sell 1 unit at price 5.870000, investment 2.802099 %, total balance 9999.718001,
# day 555: buy 1 unit at price 5.474000, total balance 9994.244001
# day 556, sell 1 unit at price 5.560000, investment 1.571063 %, total balance 9999.804001,
# day 562: buy 1 unit at price 6.210000, total balance 9993.594001
# day 563, sell 1 unit at price 6.180000, investment -0.483095 %, total balance 9999.774001,
# day 564: buy 1 unit at price 6.004000, total balance 9993.770000
# day 565, sell 1 unit at price 6.132000, investment 2.131908 %, total balance 9999.902000,
# day 573: buy 1 unit at price 5.880000, total balance 9994.022000
# day 574, sell 1 unit at price 5.778000, investment -1.734698 %, total balance 9999.800000,
# day 579: buy 1 unit at price 5.528000, total balance 9994.272000
# day 580, sell 1 unit at price 5.466000, investment -1.121559 %, total balance 9999.738000,
# day 593: buy 1 unit at price 6.300000, total balance 9993.438000
# day 594, sell 1 unit at price 6.230000, investment -1.111114 %, total balance 9999.668000,
# day 607: buy 1 unit at price 6.454000, total balance 9993.214000
# day 608, sell 1 unit at price 6.430000, investment -0.371865 %, total balance 9999.644000,
# day 614: buy 1 unit at price 6.742000, total balance 9992.902000
# day 615, sell 1 unit at price 6.780000, investment 0.563633 %, total balance 9999.682000,
# day 629: buy 1 unit at price 6.738000, total balance 9992.944000
# day 630, sell 1 unit at price 6.644000, investment -1.395071 %, total balance 9999.588000,
# day 661: buy 1 unit at price 7.690000, total balance 9991.898000
# day 662, sell 1 unit at price 7.654000, investment -0.468144 %, total balance 9999.552000,
# day 664: buy 1 unit at price 7.856000, total balance 9991.696000
# day 665, sell 1 unit at price 7.708000, investment -1.883907 %, total balance 9999.404000,
# day 667: buy 1 unit at price 7.222000, total balance 9992.182000
# day 669: buy 1 unit at price 6.886000, total balance 9985.296000
# day 670, sell 1 unit at price 7.020000, investment -2.797011 %, total balance 9992.316000,
# day 672: buy 1 unit at price 6.930000, total balance 9985.386000
# day 673, sell 1 unit at price 7.116000, investment 3.340111 %, total balance 9992.502000,
# day 674, sell 1 unit at price 7.330000, investment 5.772007 %, total balance 9999.832000,
# day 675: buy 1 unit at price 7.538000, total balance 9992.294000
# day 676, sell 1 unit at price 7.646000, investment 1.432738 %, total balance 9999.940000,
# day 678: buy 1 unit at price 7.820000, total balance 9992.120000
# day 680, sell 1 unit at price 7.796000, investment -0.306908 %, total balance 9999.916000,
# day 690: buy 1 unit at price 7.632000, total balance 9992.284000
# day 691, sell 1 unit at price 7.578000, investment -0.707546 %, total balance 9999.862000,
# day 695: buy 1 unit at price 8.402000, total balance 9991.460000
# day 697: buy 1 unit at price 8.366000, total balance 9983.093999
# day 698, sell 1 unit at price 8.100000, investment -3.594383 %, total balance 9991.194000,
# day 700, sell 1 unit at price 8.718000, investment 4.207509 %, total balance 9999.912000,
# day 706: buy 1 unit at price 9.566000, total balance 9990.346000
# day 707: buy 1 unit at price 10.038000, total balance 9980.308000
# day 708, sell 1 unit at price 10.202000, investment 6.648544 %, total balance 9990.510000,
# day 709, sell 1 unit at price 10.086000, investment 0.478186 %, total balance 10000.596000,
# day 711: buy 1 unit at price 10.240000, total balance 9990.356000
# day 713, sell 1 unit at price 10.798000, investment 5.449224 %, total balance 10001.154001,
# day 722: buy 1 unit at price 17.559999, total balance 9983.594001
# day 723, sell 1 unit at price 16.648001, investment -5.193615 %, total balance 10000.242002,
# day 724: buy 1 unit at price 16.968000, total balance 9983.274002
# day 725: buy 1 unit at price 18.450001, total balance 9964.824001
# day 728, sell 1 unit at price 17.518000, investment 3.241391 %, total balance 9982.342000,
# day 730, sell 1 unit at price 18.546000, investment 0.520318 %, total balance 10000.888000,
# day 734: buy 1 unit at price 20.990000, total balance 9979.898000
# day 736: buy 1 unit at price 18.518000, total balance 9961.380001
# day 738, sell 1 unit at price 19.073999, investment -9.128158 %, total balance 9980.454000,
# day 740: buy 1 unit at price 20.408001, total balance 9960.045999
# day 742: buy 1 unit at price 18.893999, total balance 9941.152000
# day 743: buy 1 unit at price 19.546000, total balance 9921.606000
# day 748: buy 1 unit at price 20.936001, total balance 9900.670000
# day 749, sell 1 unit at price 20.129999, investment 8.705041 %, total balance 9920.799999,
# day 750, sell 1 unit at price 19.910000, investment -2.440225 %, total balance 9940.709999,
# day 751: buy 1 unit at price 20.298000, total balance 9920.411998
# day 752: buy 1 unit at price 20.480000, total balance 9899.931999
# day 753: buy 1 unit at price 21.143999, total balance 9878.788000
# day 754, sell 1 unit at price 21.850000, investment 15.645186 %, total balance 9900.638000,
# day 756, sell 1 unit at price 23.436001, investment 19.901777 %, total balance 9924.074001,
# day 757, sell 1 unit at price 23.563999, investment 12.552533 %, total balance 9947.638000,
# day 758: buy 1 unit at price 23.048000, total balance 9924.590000
# day 759, sell 1 unit at price 24.018000, investment 18.326925 %, total balance 9948.607999,
# day 760: buy 1 unit at price 24.322001, total balance 9924.285999
# day 761: buy 1 unit at price 24.690001, total balance 9899.595998
# day 762, sell 1 unit at price 24.454000, investment 19.404302 %, total balance 9924.049999,
# day 764: buy 1 unit at price 25.980000, total balance 9898.069999
# day 765, sell 1 unit at price 25.452000, investment 20.374578 %, total balance 9923.521999,
# day 767: buy 1 unit at price 24.049999, total balance 9899.472000
# day 768, sell 1 unit at price 23.806000, investment 3.288786 %, total balance 9923.277999,
# day 769, sell 1 unit at price 23.936001, investment -1.587039 %, total balance 9947.214000,
# day 770, sell 1 unit at price 24.486000, investment -0.826247 %, total balance 9971.700000,
# day 772: buy 1 unit at price 24.340000, total balance 9947.360000
# day 773, sell 1 unit at price 24.813999, investment -4.488069 %, total balance 9972.173999,
# day 775: buy 1 unit at price 26.924000, total balance 9945.250000
# day 776, sell 1 unit at price 26.348000, investment 9.555095 %, total balance 9971.597999,
# day 779: buy 1 unit at price 27.600000, total balance 9943.997999
# day 780, sell 1 unit at price 28.936001, investment 18.882501 %, total balance 9972.934000,
# day 781, sell 1 unit at price 28.430000, investment 5.593524 %, total balance 10001.364000,
# day 782: buy 1 unit at price 26.846001, total balance 9974.517999
# day 785: buy 1 unit at price 29.476000, total balance 9945.041999
# day 786, sell 1 unit at price 29.086000, investment 5.384058 %, total balance 9974.128000,
# day 788: buy 1 unit at price 27.934000, total balance 9946.194000
# day 789, sell 1 unit at price 28.400000, investment 5.788568 %, total balance 9974.593999,
# day 791: buy 1 unit at price 29.916000, total balance 9944.677999
# day 792, sell 1 unit at price 29.572001, investment 0.325691 %, total balance 9974.250000,
# day 794: buy 1 unit at price 32.368000, total balance 9941.881999
# day 795: buy 1 unit at price 32.844002, total balance 9909.037998
# day 796: buy 1 unit at price 33.402000, total balance 9875.635997
# day 797: buy 1 unit at price 33.290001, total balance 9842.345996
# day 801, sell 1 unit at price 34.124001, investment 22.159378 %, total balance 9876.469997,
# day 802, sell 1 unit at price 33.986000, investment 13.604759 %, total balance 9910.455997,
# day 804: buy 1 unit at price 32.139999, total balance 9878.315998
# day 807, sell 1 unit at price 32.986000, investment 1.909293 %, total balance 9911.301998,
# day 808, sell 1 unit at price 33.108002, investment 0.803800 %, total balance 9944.409999,
# day 810, sell 1 unit at price 33.245998, investment -0.467044 %, total balance 9977.655998,
# day 811, sell 1 unit at price 33.243999, investment -0.138184 %, total balance 10010.899997,
# day 812: buy 1 unit at price 35.584000, total balance 9975.315998
# day 813: buy 1 unit at price 36.678001, total balance 9938.637996
# day 814: buy 1 unit at price 36.222000, total balance 9902.415996
# day 815: buy 1 unit at price 36.466000, total balance 9865.949996
# day 817: buy 1 unit at price 37.728001, total balance 9828.221996
# day 818, sell 1 unit at price 38.180000, investment 18.792785 %, total balance 9866.401996,
# day 823, sell 1 unit at price 36.195999, investment 1.719873 %, total balance 9902.597995,
# day 824, sell 1 unit at price 36.613998, investment -0.174500 %, total balance 9939.211994,
# day 825, sell 1 unit at price 34.945999, investment -3.522724 %, total balance 9974.157993,
# day 828: buy 1 unit at price 35.740002, total balance 9938.417991
# day 829, sell 1 unit at price 35.944000, investment -1.431469 %, total balance 9974.361991,
# day 830, sell 1 unit at price 36.787998, investment -2.491525 %, total balance 10011.149990,
# day 831: buy 1 unit at price 36.712002, total balance 9974.437988
# day 834: buy 1 unit at price 34.520000, total balance 9939.917987
# day 835: buy 1 unit at price 34.307999, total balance 9905.609989
# day 836, sell 1 unit at price 32.900002, investment -7.946279 %, total balance 9938.509990,
# day 840, sell 1 unit at price 32.894001, investment -10.399871 %, total balance 9971.403991,
# day 841, sell 1 unit at price 31.844000, investment -7.752029 %, total balance 10003.247991,
# day 844, sell 1 unit at price 35.040001, investment 2.133620 %, total balance 10038.287992,
# day 847: buy 1 unit at price 27.954000, total balance 10010.333992
# day 848: buy 1 unit at price 27.590000, total balance 9982.743991
# day 849: buy 1 unit at price 28.940001, total balance 9953.803991
# day 850, sell 1 unit at price 27.559999, investment -1.409462 %, total balance 9981.363990,
# day 851, sell 1 unit at price 27.740000, investment 0.543674 %, total balance 10009.103990,
# day 852: buy 1 unit at price 27.520000, total balance 9981.583990
# day 853, sell 1 unit at price 27.090000, investment -6.392537 %, total balance 10008.673990,
# day 855, sell 1 unit at price 25.218000, investment -8.364826 %, total balance 10033.891990,
# day 856: buy 1 unit at price 24.222000, total balance 10009.669990
# day 857, sell 1 unit at price 24.420000, investment 0.817438 %, total balance 10034.089990,
# day 859: buy 1 unit at price 24.167999, total balance 10009.921991
# day 860, sell 1 unit at price 24.100000, investment -0.281359 %, total balance 10034.021991,
# day 863: buy 1 unit at price 24.834000, total balance 10009.187992
# day 865, sell 1 unit at price 27.790001, investment 11.903041 %, total balance 10036.977993,
# day 866: buy 1 unit at price 28.096001, total balance 10008.881992
# day 867, sell 1 unit at price 27.472000, investment -2.220959 %, total balance 10036.353992,
# day 876: buy 1 unit at price 28.143999, total balance 10008.209993
# day 877, sell 1 unit at price 28.648001, investment 1.790796 %, total balance 10036.857994,
# day 879: buy 1 unit at price 30.282000, total balance 10006.575994
# day 880, sell 1 unit at price 31.100000, investment 2.701277 %, total balance 10037.675994,
# day 881: buy 1 unit at price 30.224001, total balance 10007.451993
# day 882: buy 1 unit at price 30.488001, total balance 9976.963993
# day 883: buy 1 unit at price 30.086000, total balance 9946.877992
# day 884: buy 1 unit at price 30.020000, total balance 9916.857992
# day 885: buy 1 unit at price 29.912001, total balance 9886.945991
# day 888, sell 1 unit at price 30.256001, investment 0.105875 %, total balance 9917.201992,
# day 890: buy 1 unit at price 29.143999, total balance 9888.057992
# day 891, sell 1 unit at price 27.868000, investment -8.593548 %, total balance 9915.925992,
# day 892: buy 1 unit at price 32.254002, total balance 9883.671991
# day 893, sell 1 unit at price 32.826000, investment 9.107225 %, total balance 9916.497991,
# day 894: buy 1 unit at price 34.194000, total balance 9882.303991
# day 895, sell 1 unit at price 34.001999, investment 13.264485 %, total balance 9916.305990,
# day 896, sell 1 unit at price 35.335999, investment 18.133183 %, total balance 9951.641988,
# day 897: buy 1 unit at price 35.712002, total balance 9915.929986
# day 898, sell 1 unit at price 36.299999, investment 24.553940 %, total balance 9952.229986,
# day 900: buy 1 unit at price 33.924000, total balance 9918.305986
# day 903: buy 1 unit at price 36.568001, total balance 9881.737985
# day 904, sell 1 unit at price 36.282001, investment 12.488373 %, total balance 9918.019987,
# day 905, sell 1 unit at price 35.422001, investment 3.591275 %, total balance 9953.441988,
# day 906: buy 1 unit at price 35.745998, total balance 9917.695989
# day 908: buy 1 unit at price 35.675999, total balance 9882.019990
# day 909, sell 1 unit at price 37.306000, investment 4.463480 %, total balance 9919.325990,
# day 910, sell 1 unit at price 39.312000, investment 15.882563 %, total balance 9958.637990,
# day 911: buy 1 unit at price 39.324001, total balance 9919.313989
# day 912: buy 1 unit at price 39.063999, total balance 9880.249990
# day 913: buy 1 unit at price 39.925999, total balance 9840.323991
# day 914: buy 1 unit at price 39.646000, total balance 9800.677991
# day 915: buy 1 unit at price 40.740002, total balance 9759.937990
# day 919, sell 1 unit at price 43.529999, investment 19.038498 %, total balance 9803.467988,
# day 920, sell 1 unit at price 49.599998, investment 38.756786 %, total balance 9853.067987,
# day 921, sell 1 unit at price 50.599998, investment 41.832045 %, total balance 9903.667985,
# day 922: buy 1 unit at price 50.507999, total balance 9853.159986
# day 925: buy 1 unit at price 50.967999, total balance 9802.191988
# day 926, sell 1 unit at price 50.532001, investment 28.501678 %, total balance 9852.723989,
# day 928, sell 1 unit at price 49.242001, investment 26.054684 %, total balance 9901.965990,
# day 931: buy 1 unit at price 48.298000, total balance 9853.667989
# day 932: buy 1 unit at price 47.557999, total balance 9806.109991
# day 933, sell 1 unit at price 46.194000, investment 15.699048 %, total balance 9852.303991,
# day 936: buy 1 unit at price 47.167999, total balance 9805.135992
# day 937, sell 1 unit at price 46.981998, investment 18.503755 %, total balance 9852.117990,
# day 938: buy 1 unit at price 45.778000, total balance 9806.339990
# day 939: buy 1 unit at price 44.034000, total balance 9762.305990
# day 942, sell 1 unit at price 41.464001, investment 1.777121 %, total balance 9803.769990,
# day 943: buy 1 unit at price 42.473999, total balance 9761.295991
# day 947, sell 1 unit at price 45.080002, investment -10.746808 %, total balance 9806.375993,
# day 948, sell 1 unit at price 42.445999, investment -16.720294 %, total balance 9848.821992,
# day 951, sell 1 unit at price 43.386002, investment -10.170191 %, total balance 9892.207994,
# day 952, sell 1 unit at price 40.838001, investment -14.130110 %, total balance 9933.045995,
# day 953, sell 1 unit at price 40.756001, investment -13.593960 %, total balance 9973.801996,
# day 954: buy 1 unit at price 39.618000, total balance 9934.183996
# day 955, sell 1 unit at price 38.782001, investment -15.282447 %, total balance 9972.965997,
# day 956, sell 1 unit at price 39.821999, investment -9.565340 %, total balance 10012.787996,
# day 957: buy 1 unit at price 39.624001, total balance 9973.163995
# day 958: buy 1 unit at price 40.875999, total balance 9932.287996
# day 959, sell 1 unit at price 43.728001, investment 2.952398 %, total balance 9976.015996,
# day 961: buy 1 unit at price 41.571999, total balance 9934.443998
# day 962, sell 1 unit at price 39.970001, investment 0.888488 %, total balance 9974.413999,
# day 963, sell 1 unit at price 39.702000, investment 0.196848 %, total balance 10014.115999,
# day 964: buy 1 unit at price 41.383999, total balance 9972.732000
# day 966: buy 1 unit at price 41.546001, total balance 9931.185998
# day 967, sell 1 unit at price 42.181999, investment 3.195028 %, total balance 9973.367998,
# day 968, sell 1 unit at price 43.321999, investment 4.209564 %, total balance 10016.689996,
# day 969: buy 1 unit at price 41.456001, total balance 9975.233995
# day 973, sell 1 unit at price 36.933998, investment -10.752950 %, total balance 10012.167993,
# day 974, sell 1 unit at price 38.032001, investment -8.458094 %, total balance 10050.199995,
# day 975, sell 1 unit at price 38.124001, investment -8.037439 %, total balance 10088.323995,
# day 976: buy 1 unit at price 37.717999, total balance 10050.605997
# day 977: buy 1 unit at price 38.312000, total balance 10012.293996
# day 978: buy 1 unit at price 39.217999, total balance 9973.075998
# day 979: buy 1 unit at price 39.060001, total balance 9934.015996
# day 980: buy 1 unit at price 39.889999, total balance 9894.125997
# day 981, sell 1 unit at price 40.976002, investment 8.637795 %, total balance 9935.101999,
# day 983, sell 1 unit at price 42.312000, investment 10.440593 %, total balance 9977.413999,
# day 985: buy 1 unit at price 42.048000, total balance 9935.365999
# day 986, sell 1 unit at price 41.554001, investment 5.956455 %, total balance 9976.920000,
# day 990, sell 1 unit at price 41.380001, investment 5.939579 %, total balance 10018.300001,
# day 991, sell 1 unit at price 41.633999, investment 4.372022 %, total balance 10059.934000,
# day 992, sell 1 unit at price 41.062000, investment -2.344939 %, total balance 10100.996000,
# day 995: buy 1 unit at price 40.703999, total balance 10060.292001
# day 996: buy 1 unit at price 41.284000, total balance 10019.008001
# day 997, sell 1 unit at price 44.922001, investment 10.362624 %, total balance 10063.930002,
# day 998: buy 1 unit at price 46.334000, total balance 10017.596002
# day 999: buy 1 unit at price 45.424000, total balance 9972.172002
# day 1000: buy 1 unit at price 45.557999, total balance 9926.614004
# day 1001: buy 1 unit at price 45.917999, total balance 9880.696004
# day 1002: buy 1 unit at price 47.444000, total balance 9833.252004
# day 1008, sell 1 unit at price 47.944000, investment 16.132157 %, total balance 9881.196004,
# day 1009: buy 1 unit at price 45.886002, total balance 9835.310003
# day 1010, sell 1 unit at price 45.849998, investment -1.044592 %, total balance 9881.160001,
# day 1012: buy 1 unit at price 43.813999, total balance 9837.346002
# day 1013, sell 1 unit at price 44.612000, investment -1.787602 %, total balance 9881.958002,
# day 1014, sell 1 unit at price 43.891998, investment -3.656878 %, total balance 9925.850000,
# day 1015, sell 1 unit at price 43.625999, investment -4.991506 %, total balance 9969.475999,
# day 1016: buy 1 unit at price 45.340000, total balance 9924.135999
# day 1018: buy 1 unit at price 43.431999, total balance 9880.704000
# day 1019: buy 1 unit at price 43.080002, total balance 9837.623998
# day 1024, sell 1 unit at price 44.708000, investment -5.766799 %, total balance 9882.331998,
# day 1025, sell 1 unit at price 44.714001, investment -2.554158 %, total balance 9927.045999,
# day 1026, sell 1 unit at price 44.964001, investment 2.624735 %, total balance 9972.010000,
# day 1027: buy 1 unit at price 45.001999, total balance 9927.008001
# day 1028: buy 1 unit at price 45.784000, total balance 9881.224000
# day 1029, sell 1 unit at price 44.660000, investment -1.499780 %, total balance 9925.884000,
# day 1031, sell 1 unit at price 47.703999, investment 9.836064 %, total balance 9973.587999,
# day 1032, sell 1 unit at price 47.698002, investment 10.719591 %, total balance 10021.286001,
# day 1033, sell 1 unit at price 49.785999, investment 10.630640 %, total balance 10071.072000,
# day 1034, sell 1 unit at price 50.478001, investment 10.252490 %, total balance 10121.550001,
# day 1035: buy 1 unit at price 49.625999, total balance 10071.924001
# day 1036: buy 1 unit at price 51.863998, total balance 10020.060003
# day 1037, sell 1 unit at price 51.992001, investment 4.767664 %, total balance 10072.052003,
# day 1038: buy 1 unit at price 52.062000, total balance 10019.990003
# day 1039: buy 1 unit at price 52.276001, total balance 9967.714002
# day 1041: buy 1 unit at price 51.987999, total balance 9915.726003
# day 1042: buy 1 unit at price 51.352001, total balance 9864.374002
# day 1044: buy 1 unit at price 50.868000, total balance 9813.506002
# day 1047, sell 1 unit at price 52.348000, investment 0.933212 %, total balance 9865.854002,
# day 1048: buy 1 unit at price 52.650002, total balance 9813.204000
# day 1050: buy 1 unit at price 53.939999, total balance 9759.264001
# day 1051: buy 1 unit at price 56.824001, total balance 9702.440000
# day 1052, sell 1 unit at price 56.237999, investment 8.021203 %, total balance 9758.677999,
# day 1053: buy 1 unit at price 57.208000, total balance 9701.469999
# day 1054: buy 1 unit at price 55.478001, total balance 9645.991998
# day 1058, sell 1 unit at price 56.062000, investment 7.242328 %, total balance 9702.053998,
# day 1063, sell 1 unit at price 52.764000, investment 1.492654 %, total balance 9754.817998,
# day 1064, sell 1 unit at price 51.863998, investment 0.997035 %, total balance 9806.681997,
# day 1066: buy 1 unit at price 50.082001, total balance 9756.599996
# day 1067: buy 1 unit at price 50.428001, total balance 9706.171995
# day 1068, sell 1 unit at price 49.389999, investment -2.905561 %, total balance 9755.561994,
# day 1069: buy 1 unit at price 49.320000, total balance 9706.241994
# day 1073, sell 1 unit at price 50.284000, investment -4.493829 %, total balance 9756.525995,
# day 1074, sell 1 unit at price 51.042000, investment -5.372634 %, total balance 9807.567995,
# day 1075, sell 1 unit at price 52.124001, investment -8.271154 %, total balance 9859.691995,
# day 1079, sell 1 unit at price 47.382000, investment -17.175920 %, total balance 9907.073995,
# day 1083, sell 1 unit at price 45.270000, investment -18.400087 %, total balance 9952.343996,
# day 1084, sell 1 unit at price 45.495998, investment -9.156987 %, total balance 9997.839994,
# day 1085, sell 1 unit at price 46.094002, investment -8.594431 %, total balance 10043.933996,
# day 1086, sell 1 unit at price 47.068001, investment -4.566097 %, total balance 10091.001997,
# day 1087: buy 1 unit at price 46.220001, total balance 10044.781995
# day 1088: buy 1 unit at price 47.057999, total balance 9997.723997
# day 1089: buy 1 unit at price 47.048000, total balance 9950.675996
# day 1091, sell 1 unit at price 48.554001, investment 5.049761 %, total balance 9999.229997,
# day 1092, sell 1 unit at price 47.619999, investment 1.194272 %, total balance 10046.849996,
# day 1093: buy 1 unit at price 47.731998, total balance 9999.117998
# day 1094, sell 1 unit at price 48.340000, investment 2.746131 %, total balance 10047.457998,
# day 1096: buy 1 unit at price 47.785999, total balance 9999.671999
# day 1099, sell 1 unit at price 48.040001, investment 0.645275 %, total balance 10047.711999,
# day 1100, sell 1 unit at price 48.386002, investment 1.255603 %, total balance 10096.098001,
# day 1103: buy 1 unit at price 50.340000, total balance 10045.758001
# day 1104, sell 1 unit at price 51.736000, investment 2.773142 %, total balance 10097.494001,
# day 1106: buy 1 unit at price 51.540001, total balance 10045.954000
# day 1109, sell 1 unit at price 48.556000, investment -5.789680 %, total balance 10094.510000,
# day 1112: buy 1 unit at price 49.688000, total balance 10044.822000
# day 1113, sell 1 unit at price 48.903999, investment -1.577847 %, total balance 10093.725999,
# day 1114: buy 1 unit at price 46.327999, total balance 10047.398000
# day 1115: buy 1 unit at price 46.285999, total balance 10001.112001
# day 1116, sell 1 unit at price 45.860001, investment -1.010185 %, total balance 10046.972002,
# day 1117: buy 1 unit at price 45.655998, total balance 10001.316003
# day 1118, sell 1 unit at price 44.742001, investment -3.335779 %, total balance 10046.058004,
# day 1119, sell 1 unit at price 42.872002, investment -6.097767 %, total balance 10088.930006,
# day 1120: buy 1 unit at price 43.377998, total balance 10045.552007
# day 1121: buy 1 unit at price 41.967999, total balance 10003.584009
# day 1122, sell 1 unit at price 41.776001, investment -3.693110 %, total balance 10045.360010,
# day 1123, sell 1 unit at price 41.400002, investment -1.353405 %, total balance 10086.760011,
# day 1124: buy 1 unit at price 40.807999, total balance 10045.952013
# day 1128, sell 1 unit at price 43.858002, investment 7.474032 %, total balance 10089.810014,
# day 1131: buy 1 unit at price 44.452000, total balance 10045.358015
# day 1132: buy 1 unit at price 45.563999, total balance 9999.794015
# day 1133, sell 1 unit at price 45.141998, investment 1.552233 %, total balance 10044.936014,
# day 1134: buy 1 unit at price 44.445999, total balance 10000.490015
# day 1135, sell 1 unit at price 44.481998, investment -2.374683 %, total balance 10044.972013,
# day 1137, sell 1 unit at price 42.018002, investment -5.462803 %, total balance 10086.990015,
# day 1143: buy 1 unit at price 40.849998, total balance 10046.140016
# day 1144, sell 1 unit at price 38.537998, investment -5.659732 %, total balance 10084.678014,
# day 1146: buy 1 unit at price 38.613998, total balance 10046.064016
# day 1147: buy 1 unit at price 38.386002, total balance 10007.678014
# day 1148: buy 1 unit at price 39.313999, total balance 9968.364015
# day 1149: buy 1 unit at price 40.324001, total balance 9928.040014
# day 1150: buy 1 unit at price 40.257999, total balance 9887.782014
# day 1151, sell 1 unit at price 41.310001, investment 6.981932 %, total balance 9929.092016,
# day 1153: buy 1 unit at price 39.874001, total balance 9889.218015
# day 1154: buy 1 unit at price 41.040001, total balance 9848.178014
# day 1156, sell 1 unit at price 42.188000, investment 9.904647 %, total balance 9890.366014,
# day 1157, sell 1 unit at price 43.672001, investment 11.085114 %, total balance 9934.038015,
# day 1158, sell 1 unit at price 43.709999, investment 8.396979 %, total balance 9977.748014,
# day 1159, sell 1 unit at price 44.198002, investment 9.786881 %, total balance 10021.946016,
# day 1160, sell 1 unit at price 43.472000, investment 9.023423 %, total balance 10065.418016,
# day 1161: buy 1 unit at price 43.495998, total balance 10021.922018
# day 1162: buy 1 unit at price 43.257999, total balance 9978.664018
# day 1163, sell 1 unit at price 42.560001, investment 3.703705 %, total balance 10021.224020,
# day 1165, sell 1 unit at price 40.754002, investment -6.304021 %, total balance 10061.978021,
# day 1167, sell 1 unit at price 40.891998, investment -5.469511 %, total balance 10102.870019,
# day 1169: buy 1 unit at price 43.422001, total balance 10059.448019
# day 1170: buy 1 unit at price 41.467999, total balance 10017.980020
# day 1171: buy 1 unit at price 40.821999, total balance 9977.158021
# day 1173: buy 1 unit at price 41.438000, total balance 9935.720022
# day 1174, sell 1 unit at price 40.667999, investment -6.342411 %, total balance 9976.388021,
# day 1177: buy 1 unit at price 40.487999, total balance 9935.900022
# day 1178, sell 1 unit at price 40.125999, investment -3.236228 %, total balance 9976.026021,
# day 1179, sell 1 unit at price 38.776001, investment -5.011998 %, total balance 10014.802022,
# day 1180: buy 1 unit at price 38.175999, total balance 9976.626024
# day 1184, sell 1 unit at price 37.736000, investment -8.933828 %, total balance 10014.362024,
# day 1185, sell 1 unit at price 39.139999, investment -3.329381 %, total balance 10053.502023,
# day 1186, sell 1 unit at price 38.945999, investment 2.016975 %, total balance 10092.448022,
# day 1187: buy 1 unit at price 40.141998, total balance 10052.306024
# day 1188: buy 1 unit at price 39.130001, total balance 10013.176023
# day 1189: buy 1 unit at price 39.616001, total balance 9973.560022
# day 1190, sell 1 unit at price 39.925999, investment -0.538089 %, total balance 10013.486021,
# day 1193, sell 1 unit at price 38.082001, investment -2.678253 %, total balance 10051.568021,
# day 1195, sell 1 unit at price 38.113998, investment -3.791404 %, total balance 10089.682020,
# day 1199: buy 1 unit at price 40.619999, total balance 10049.062021
# day 1200, sell 1 unit at price 40.650002, investment 0.073862 %, total balance 10089.712022,
# day 1201: buy 1 unit at price 41.534000, total balance 10048.178022
# day 1202: buy 1 unit at price 42.018002, total balance 10006.160020
# day 1203: buy 1 unit at price 42.180000, total balance 9963.980020
# day 1204: buy 1 unit at price 41.956001, total balance 9922.024019
# day 1206: buy 1 unit at price 41.566002, total balance 9880.458017
# day 1207, sell 1 unit at price 41.340000, investment -0.467088 %, total balance 9921.798017,
# day 1209, sell 1 unit at price 41.054001, investment -2.294256 %, total balance 9962.852018,
# day 1211, sell 1 unit at price 43.888000, investment 4.049313 %, total balance 10006.740018,
# day 1212, sell 1 unit at price 43.720001, investment 4.204404 %, total balance 10050.460020,
# day 1213: buy 1 unit at price 43.686001, total balance 10006.774019
# day 1215, sell 1 unit at price 46.096001, investment 10.898327 %, total balance 10052.870019,
# day 1216: buy 1 unit at price 46.490002, total balance 10006.380018
# day 1217, sell 1 unit at price 45.209999, investment 3.488528 %, total balance 10051.590017,
# day 1218: buy 1 unit at price 45.206001, total balance 10006.384016
# day 1219: buy 1 unit at price 46.102001, total balance 9960.282014
# day 1221: buy 1 unit at price 46.085999, total balance 9914.196016
# day 1222: buy 1 unit at price 47.360001, total balance 9866.836015
# day 1223, sell 1 unit at price 47.321999, investment 1.789625 %, total balance 9914.158014,
# day 1227, sell 1 unit at price 48.820000, investment 7.994510 %, total balance 9962.978014,
# day 1230: buy 1 unit at price 49.428001, total balance 9913.550012
# day 1232: buy 1 unit at price 49.124001, total balance 9864.426012
# day 1233: buy 1 unit at price 49.546001, total balance 9814.880010
# day 1236, sell 1 unit at price 50.290001, investment 9.084204 %, total balance 9865.170011,
# day 1238, sell 1 unit at price 49.889999, investment 8.254136 %, total balance 9915.060010,
# day 1240: buy 1 unit at price 49.798000, total balance 9865.262010
# day 1241, sell 1 unit at price 49.183998, investment 3.851346 %, total balance 9914.446008,
# day 1242: buy 1 unit at price 49.827999, total balance 9864.618009
# day 1243, sell 1 unit at price 51.257999, investment 3.702351 %, total balance 9915.876009,
# day 1244, sell 1 unit at price 51.200001, investment 4.226041 %, total balance 9967.076009,
# day 1245: buy 1 unit at price 50.139999, total balance 9916.936010
# day 1246: buy 1 unit at price 50.282001, total balance 9866.654008
# day 1248: buy 1 unit at price 50.076000, total balance 9816.578008
# day 1251: buy 1 unit at price 52.377998, total balance 9764.200010
# day 1252, sell 1 unit at price 52.501999, investment 5.966168 %, total balance 9816.702009,
# day 1254: buy 1 unit at price 53.534000, total balance 9763.168008
# day 1255, sell 1 unit at price 53.034000, investment 6.498253 %, total balance 9816.202009,
# day 1256, sell 1 unit at price 53.757999, investment 7.887132 %, total balance 9869.960008,
# day 1260, sell 1 unit at price 53.830002, investment 7.359399 %, total balance 9923.790010,
# day 1261, sell 1 unit at price 56.004002, investment 11.379818 %, total balance 9979.794012,
# day 1262: buy 1 unit at price 55.944000, total balance 9923.850011
# day 1264: buy 1 unit at price 50.992001, total balance 9872.858011
# day 1267, sell 1 unit at price 52.431999, investment 4.704847 %, total balance 9925.290010,
# day 1268, sell 1 unit at price 53.130001, investment 1.435723 %, total balance 9978.420011,
# day 1270: buy 1 unit at price 53.335999, total balance 9925.084013
# day 1271, sell 1 unit at price 54.931999, investment 2.611422 %, total balance 9980.016012,
# day 1272: buy 1 unit at price 56.452000, total balance 9923.564012
# day 1273: buy 1 unit at price 53.354000, total balance 9870.210012
# day 1277, sell 1 unit at price 50.602001, investment -9.548833 %, total balance 9920.812013,
# day 1278, sell 1 unit at price 52.964001, investment 3.867273 %, total balance 9973.776014,
# day 1279, sell 1 unit at price 52.764000, investment -1.072444 %, total balance 10026.540014,
# day 1280: buy 1 unit at price 53.358002, total balance 9973.182012
# day 1282: buy 1 unit at price 51.998001, total balance 9921.184011
# day 1283: buy 1 unit at price 53.256001, total balance 9867.928010
# day 1284, sell 1 unit at price 54.026001, investment -4.297454 %, total balance 9921.954011,
# day 1286: buy 1 unit at price 48.501999, total balance 9873.452013
# day 1288, sell 1 unit at price 47.473999, investment -11.020731 %, total balance 9920.926012,
# day 1289, sell 1 unit at price 47.633999, investment -10.727543 %, total balance 9968.560010,
# day 1290, sell 1 unit at price 48.501999, investment -6.723340 %, total balance 10017.062009,
# day 1291: buy 1 unit at price 48.630001, total balance 9968.432008
# day 1292: buy 1 unit at price 50.998001, total balance 9917.434007
# day 1294: buy 1 unit at price 51.049999, total balance 9866.384008
# day 1295: buy 1 unit at price 48.436001, total balance 9817.948007
# day 1299, sell 1 unit at price 44.967999, investment -15.562569 %, total balance 9862.916006,
# day 1300, sell 1 unit at price 48.598000, investment 0.197931 %, total balance 9911.514005,
# day 1301, sell 1 unit at price 49.695999, investment 2.192059 %, total balance 9961.210004,
# day 1302, sell 1 unit at price 49.812000, investment -2.325583 %, total balance 10011.022005,
# day 1303: buy 1 unit at price 47.726002, total balance 9963.296003
# day 1304: buy 1 unit at price 49.537998, total balance 9913.758005
# day 1305, sell 1 unit at price 49.113998, investment -3.792362 %, total balance 9962.872003,
# day 1308, sell 1 unit at price 49.782001, investment 2.778926 %, total balance 10012.654005,
# day 1309, sell 1 unit at price 49.695999, investment 4.127724 %, total balance 10062.350004,
# day 1310, sell 1 unit at price 50.048000, investment 1.029517 %, total balance 10112.398004,
# day 1312: buy 1 unit at price 50.714001, total balance 10061.684003
# day 1313: buy 1 unit at price 52.450001, total balance 10009.234003
# day 1316, sell 1 unit at price 52.840000, investment 4.192135 %, total balance 10062.074003,
# day 1317, sell 1 unit at price 52.188000, investment -0.499525 %, total balance 10114.262002,
# day 1321: buy 1 unit at price 49.686001, total balance 10064.576002
# day 1322: buy 1 unit at price 49.330002, total balance 10015.246000
# day 1324, sell 1 unit at price 47.976002, investment -3.441611 %, total balance 10063.222002,
# day 1327: buy 1 unit at price 48.292000, total balance 10014.930002
# day 1328, sell 1 unit at price 46.391998, investment -5.955815 %, total balance 10061.322000,
# day 1329, sell 1 unit at price 45.344002, investment -6.104527 %, total balance 10106.666002,
# day 1330: buy 1 unit at price 44.138000, total balance 10062.528001
# day 1331, sell 1 unit at price 43.116001, investment -2.315464 %, total balance 10105.644002,
# day 1333: buy 1 unit at price 43.375999, total balance 10062.268003
# day 1334: buy 1 unit at price 44.262001, total balance 10018.006002
# day 1335, sell 1 unit at price 45.402000, investment 4.670788 %, total balance 10063.408002,
# day 1336, sell 1 unit at price 45.619999, investment 3.068090 %, total balance 10109.028001,
# day 1337: buy 1 unit at price 42.605999, total balance 10066.422002
# day 1340, sell 1 unit at price 41.818001, investment -1.849501 %, total balance 10108.240003,
# day 1346: buy 1 unit at price 42.757999, total balance 10065.482004
# day 1347, sell 1 unit at price 41.669998, investment -2.544556 %, total balance 10107.152002,
# day 1351: buy 1 unit at price 45.066002, total balance 10062.086000
# day 1352, sell 1 unit at price 43.299999, investment -3.918703 %, total balance 10105.385999,
# day 1353: buy 1 unit at price 43.816002, total balance 10061.569997
# day 1354, sell 1 unit at price 42.588001, investment -2.802631 %, total balance 10104.157999,
# day 1356: buy 1 unit at price 42.862000, total balance 10061.295999
# day 1357, sell 1 unit at price 42.799999, investment -0.144651 %, total balance 10104.095998,
# day 1360: buy 1 unit at price 44.001999, total balance 10060.093999
# day 1361: buy 1 unit at price 43.549999, total balance 10016.544000
# day 1362: buy 1 unit at price 43.650002, total balance 9972.893999
# day 1364: buy 1 unit at price 46.321999, total balance 9926.572000
# day 1366, sell 1 unit at price 47.438000, investment 7.808738 %, total balance 9974.010000,
# ...
# day 2515: buy 1 unit at price 197.195999, total balance 7841.487998
# day 2518: buy 1 unit at price 215.962006, total balance 7625.525993
# day 2519, sell 1 unit at price 223.925995, investment 209.957899 %, total balance 7849.451988,
# day 2520: buy 1 unit at price 241.731995, total balance 7607.719993
# day 2521, sell 1 unit at price 274.316010, investment 220.814937 %, total balance 7882.036003,
# day 2522: buy 1 unit at price 277.971985, total balance 7604.064018
# day 2523: buy 1 unit at price 273.175995, total balance 7330.888023
# day 2525: buy 1 unit at price 308.929993, total balance 7021.958030
# day 2526, sell 1 unit at price 299.411987, investment 198.141895 %, total balance 7321.370018,
# day 2529, sell 1 unit at price 300.127991, investment 186.381662 %, total balance 7621.498008,
# day 2531, sell 1 unit at price 328.600006, investment 120.474759 %, total balance 7950.098014,
# day 2532, sell 1 unit at price 313.671997, investment 128.384211 %, total balance 8263.770011,
# day 2533: buy 1 unit at price 318.466003, total balance 7945.304008
# day 2536: buy 1 unit at price 307.920013, total balance 7637.383995
# day 2537, sell 1 unit at price 295.298004, investment 101.675985 %, total balance 7932.681999,
# day 2538: buy 1 unit at price 299.821991, total balance 7632.860008
# day 2539: buy 1 unit at price 297.497986, total balance 7335.362022
# day 2541: buy 1 unit at price 297.000000, total balance 7038.362022
# day 2542: buy 1 unit at price 297.399994, total balance 6740.962028
# day 2543: buy 1 unit at price 297.003998, total balance 6443.958030
# day 2544: buy 1 unit at price 297.915985, total balance 6146.042045
# day 2549, sell 1 unit at price 324.200012, investment 129.723790 %, total balance 6470.242057,
# day 2551: buy 1 unit at price 367.127991, total balance 6103.114067
# day 2552, sell 1 unit at price 377.417999, investment 147.913125 %, total balance 6480.532066,
# day 2553: buy 1 unit at price 375.705994, total balance 6104.826072
# day 2554: buy 1 unit at price 400.365997, total balance 5704.460075
# day 2555, sell 1 unit at price 409.996002, investment 162.804480 %, total balance 6114.456077,
# day 2556: buy 1 unit at price 402.839996, total balance 5711.616081
# day 2559: buy 1 unit at price 447.750000, total balance 5263.866081
# day 2560, sell 1 unit at price 442.679993, investment 172.824763 %, total balance 5706.546073,
# day 2561, sell 1 unit at price 498.320007, investment 207.829157 %, total balance 6204.866081,
# day 2562: buy 1 unit at price 475.049988, total balance 5729.816093
# day 2563: buy 1 unit at price 447.369995, total balance 5282.446098
# day 2566, sell 1 unit at price 330.209991, investment 105.525743 %, total balance 5612.656089,
# day 2569: buy 1 unit at price 372.720001, total balance 5239.936088
# day 2570: buy 1 unit at price 419.619995, total balance 4820.316093
# day 2571, sell 1 unit at price 449.760010, investment 174.622348 %, total balance 5270.076103,
# day 2572: buy 1 unit at price 441.760010, total balance 4828.316093
# day 2573: buy 1 unit at price 423.429993, total balance 4404.886100
# day 2575: buy 1 unit at price 449.390015, total balance 3955.496086
# day 2579, sell 1 unit at price 407.339996, investment 148.308391 %, total balance 4362.836082,
# day 2581, sell 1 unit at price 419.070007, investment 150.940124 %, total balance 4781.906089,
# day 2582: buy 1 unit at price 429.010010, total balance 4352.896080
# day 2583, sell 1 unit at price 448.160004, investment 153.782740 %, total balance 4801.056083,
# day 2586, sell 1 unit at price 413.980011, investment 133.712713 %, total balance 5215.036094,
# day 2587, sell 1 unit at price 425.299988, investment 123.860958 %, total balance 5640.336082,
# day 2588, sell 1 unit at price 425.920013, investment 107.755731 %, total balance 6066.256095,
# day 2589, sell 1 unit at price 434.000000, investment 118.796316 %, total balance 6500.256095,
# day 2590: buy 1 unit at price 442.299988, total balance 6057.956108
# day 2591: buy 1 unit at price 446.649994, total balance 5611.306114
# day 2592, sell 1 unit at price 461.299988, investment 131.967572 %, total balance 6072.606102,
# day 2593: buy 1 unit at price 448.880005, total balance 5623.726097
# day 2598, sell 1 unit at price 425.790009, investment 115.922235 %, total balance 6049.516105,
# day 2599, sell 1 unit at price 420.630005, investment 94.770373 %, total balance 6470.146110,
# day 2600: buy 1 unit at price 420.279999, total balance 6049.866111
# day 2601: buy 1 unit at price 424.679993, total balance 5625.186119
# day 2602: buy 1 unit at price 406.019989, total balance 5219.166130
# day 2603: buy 1 unit at price 410.829987, total balance 4808.336143
# day 2607, sell 1 unit at price 420.980011, investment 74.151548 %, total balance 5229.316154,
# day 2608: buy 1 unit at price 438.089996, total balance 4791.226158
# day 2609: buy 1 unit at price 429.950012, total balance 4361.276145
# day 2610, sell 1 unit at price 421.260010, investment 51.547650 %, total balance 4782.536155,
# day 2611: buy 1 unit at price 410.359985, total balance 4372.176170
# day 2613: buy 1 unit at price 411.760010, total balance 3960.416160
# day 2614, sell 1 unit at price 408.500000, investment 49.537297 %, total balance 4368.916160,
# day 2616, sell 1 unit at price 441.609985, investment 42.948239 %, total balance 4810.526145,
# day 2617, sell 1 unit at price 486.640015, investment 52.807524 %, total balance 5297.166160,
# day 2618, sell 1 unit at price 499.269989, investment 62.142754 %, total balance 5796.436149,
# day 2619, sell 1 unit at price 489.609985, investment 63.300225 %, total balance 6286.046134,
# day 2620: buy 1 unit at price 521.849976, total balance 5764.196159
# day 2621: buy 1 unit at price 555.380005, total balance 5208.816154
# day 2622: buy 1 unit at price 574.000000, total balance 4634.816154
# day 2623, sell 1 unit at price 585.760010, investment 96.895454 %, total balance 5220.576164,
# day 2624: buy 1 unit at price 567.599976, total balance 4652.976188
# day 2628, sell 1 unit at price 599.039978, investment 101.696962 %, total balance 5252.016166,
# day 2629: buy 1 unit at price 641.760010, total balance 4610.256156
# day 2630, sell 1 unit at price 649.880005, investment 118.520517 %, total balance 5260.136161,
# day 2633, sell 1 unit at price 609.989990, investment 105.381071 %, total balance 5870.126152,
# day 2634, sell 1 unit at price 639.830017, investment 114.768609 %, total balance 6509.956169,
# day 2635, sell 1 unit at price 633.250000, investment 72.487529 %, total balance 7143.206169,
# day 2637: buy 1 unit at price 655.900024, total balance 6487.306144
# day 2638, sell 1 unit at price 695.000000, investment 84.985071 %, total balance 7182.306144,
# day 2639: buy 1 unit at price 649.859985, total balance 6532.446159
# day 2640: buy 1 unit at price 640.340027, total balance 5892.106132
# day 2645, sell 1 unit at price 694.780029, investment 73.536223 %, total balance 6586.886161,
# day 2646: buy 1 unit at price 705.669983, total balance 5881.216178
# day 2648: buy 1 unit at price 735.109985, total balance 5146.106193
# day 2649: buy 1 unit at price 755.979980, total balance 4390.126213
# day 2650: buy 1 unit at price 816.039978, total balance 3574.086235
# day 2651, sell 1 unit at price 880.020020, investment 118.453984 %, total balance 4454.106254,
# day 2653: buy 1 unit at price 849.440002, total balance 3604.666252
# day 2654, sell 1 unit at price 854.409973, investment 90.822998 %, total balance 4459.076225,
# day 2655: buy 1 unit at price 845.000000, total balance 3614.076225
# day 2656, sell 1 unit at price 826.159973, investment 73.910114 %, total balance 4440.236198,
# day 2658: buy 1 unit at price 850.450012, total balance 3589.786186
# day 2659, sell 1 unit at price 844.989990, investment 88.879451 %, total balance 4434.776176,
# day 2661: buy 1 unit at price 880.799988, total balance 3553.976188
# day 2662, sell 1 unit at price 883.090027, investment 136.931215 %, total balance 4437.066215,
# day 2665: buy 1 unit at price 793.530029, total balance 3643.536186
# day 2667, sell 1 unit at price 872.789978, investment 107.995326 %, total balance 4516.326164,
# day 2668: buy 1 unit at price 854.690002, total balance 3661.636161
# day 2669: buy 1 unit at price 849.989990, total balance 2811.646171
# day 2671: buy 1 unit at price 863.419983, total balance 1948.226188
# day 2672: buy 1 unit at price 849.460022, total balance 1098.766166
# day 2677: buy 1 unit at price 798.150024, total balance 300.616142
# day 2678, sell 1 unit at price 787.380005, investment 78.237049 %, total balance 1087.996147,
# day 2679: buy 1 unit at price 781.299988, total balance 306.696159
# day 2683, sell 1 unit at price 682.219971, investment 61.117536 %, total balance 988.916130,
# day 2684, sell 1 unit at price 675.500000, investment 50.314866 %, total balance 1664.416130,
# day 2685, sell 1 unit at price 718.429993, investment 67.462291 %, total balance 2382.846122,
# day 2687: buy 1 unit at price 653.200012, total balance 1729.646110
# day 2688, sell 1 unit at price 621.440002, investment 40.501926 %, total balance 2351.086112,
# day 2689: buy 1 unit at price 597.950012, total balance 1753.136100
# day 2690: buy 1 unit at price 563.000000, total balance 1190.136100
# day 2693: buy 1 unit at price 699.599976, total balance 490.536125
# day 2694, sell 1 unit at price 693.729980, investment 55.318480 %, total balance 1184.266105,
# day 2695, sell 1 unit at price 707.940002, investment 57.712528 %, total balance 1892.206108,
# day 2696: buy 1 unit at price 676.880005, total balance 1215.326103
# day 2697: buy 1 unit at price 701.809998, total balance 513.516105
# day 2702, sell 1 unit at price 630.270020, investment 49.964315 %, total balance 1143.786125,
# day 2703, sell 1 unit at price 640.390015, investment 50.793545 %, total balance 1784.176139,
# day 2704, sell 1 unit at price 618.710022, investment 52.384129 %, total balance 2402.886161,
# day 2705: buy 1 unit at price 611.289978, total balance 1791.596183
# day 2706, sell 1 unit at price 635.619995, investment 54.716066 %, total balance 2427.216178,
# day 2707, sell 1 unit at price 667.929993, investment 52.464105 %, total balance 3095.146171,
# day 2708: buy 1 unit at price 661.750000, total balance 2433.396171
# day 2709, sell 1 unit at price 691.049988, investment 60.727984 %, total balance 3124.446159,
# day 2711: buy 1 unit at price 670.969971, total balance 2453.476188
# day 2712: buy 1 unit at price 683.799988, total balance 1769.676200
# day 2713, sell 1 unit at price 677.020020, investment 64.981978 %, total balance 2446.696220,
# day 2714: buy 1 unit at price 701.979980, total balance 1744.716239
# day 2715, sell 1 unit at price 762.320007, investment 85.136970 %, total balance 2507.036247,
# day 2717: buy 1 unit at price 738.849976, total balance 1768.186271
# day 2719, sell 1 unit at price 714.630005, investment 36.941657 %, total balance 2482.816276,
# day 2720: buy 1 unit at price 718.989990, total balance 1763.826286
# day 2721, sell 1 unit at price 744.119995, investment 33.983937 %, total balance 2507.946281,
# day 2723: buy 1 unit at price 729.400024, total balance 1778.546257
# day 2724, sell 1 unit at price 738.200012, investment 28.606274 %, total balance 2516.746269,
# day 2725, sell 1 unit at price 704.739990, investment 24.161385 %, total balance 3221.486259,
# day 2726: buy 1 unit at price 694.400024, total balance 2527.086235
# day 2727, sell 1 unit at price 677.000000, investment 5.491148 %, total balance 3204.086235,
# day 2728: buy 1 unit at price 709.440002, total balance 2494.646232
# day 2729: buy 1 unit at price 684.900024, total balance 1809.746208
# day 2731, sell 1 unit at price 670.940002, investment 2.293029 %, total balance 2480.686210,
# day 2734, sell 1 unit at price 629.039978, investment -3.203768 %, total balance 3109.726188,
# day 2735: buy 1 unit at price 617.200012, total balance 2492.526176
# day 2736: buy 1 unit at price 589.890015, total balance 1902.636161
# day 2739, sell 1 unit at price 576.830017, investment -9.918170 %, total balance 2479.466178,
# day 2741: buy 1 unit at price 563.460022, total balance 1916.006156
# day 2742, sell 1 unit at price 586.780029, investment -16.847812 %, total balance 2502.786186,
# day 2743: buy 1 unit at price 580.880005, total balance 1921.906181
# day 2744: buy 1 unit at price 606.440002, total balance 1315.466178
# day 2745, sell 1 unit at price 604.690002, investment -17.741561 %, total balance 1920.156181,
# day 2746: buy 1 unit at price 619.130005, total balance 1301.026176
# day 2748, sell 1 unit at price 625.219971, investment -17.296756 %, total balance 1926.246147,
# day 2749: buy 1 unit at price 623.900024, total balance 1302.346122
# day 2750, sell 1 unit at price 605.119995, investment -25.846771 %, total balance 1907.466117,
# day 2751, sell 1 unit at price 572.840027, investment -32.562627 %, total balance 2480.306144,
# day 2752: buy 1 unit at price 599.049988, total balance 1881.256156
# day 2754: buy 1 unit at price 603.590027, total balance 1277.666130
# day 2755, sell 1 unit at price 598.780029, investment -29.138458 %, total balance 1876.446159,
# day 2756, sell 1 unit at price 610.119995, investment -28.259159 %, total balance 2486.566154,
# day 2757, sell 1 unit at price 609.890015, investment -30.757263 %, total balance 3096.456169,
# day 2758: buy 1 unit at price 617.690002, total balance 2478.766166
# day 2759: buy 1 unit at price 599.359985, total balance 1879.406181
# day 2760, sell 1 unit at price 604.869995, investment -23.774782 %, total balance 2484.276176,
# day 2761: buy 1 unit at price 616.599976, total balance 1867.676200
# day 2762, sell 1 unit at price 623.309998, investment -27.071804 %, total balance 2490.986198,
# day 2763: buy 1 unit at price 620.830017, total balance 1870.156181
# day 2764: buy 1 unit at price 623.710022, total balance 1246.446159
# day 2765: buy 1 unit at price 656.570007, total balance 589.876152
# day 2766, sell 1 unit at price 679.820007, investment -20.020234 %, total balance 1269.696159,
# day 2768: buy 1 unit at price 688.719971, total balance 580.976188
# day 2774, sell 1 unit at price 644.650024, investment -25.337607 %, total balance 1225.626213,
# day 2776, sell 1 unit at price 656.950012, investment -22.662633 %, total balance 1882.576225,
# day 2777, sell 1 unit at price 685.700012, investment -14.088832 %, total balance 2568.276237,
# day 2778, sell 1 unit at price 668.539978, investment -14.432358 %, total balance 3236.816215,
# day 2779: buy 1 unit at price 653.380005, total balance 2583.436210
# day 2780: buy 1 unit at price 650.599976, total balance 1932.836235
# day 2782: buy 1 unit at price 646.219971, total balance 1286.616264
# day 2783, sell 1 unit at price 660.500000, investment 1.117573 %, total balance 1947.116264,
# day 2784: buy 1 unit at price 655.289978, total balance 1291.826286
# day 2785: buy 1 unit at price 649.260010, total balance 642.566276
# day 2793, sell 1 unit at price 709.739990, investment 18.695539 %, total balance 1352.306266,
# day 2794: buy 1 unit at price 710.919983, total balance 641.386283
# day 2799, sell 1 unit at price 707.820007, investment 25.722914 %, total balance 1349.206291,
# day 2800, sell 1 unit at price 722.250000, investment 3.237568 %, total balance 2071.456291,
# day 2801, sell 1 unit at price 717.169983, investment 5.952307 %, total balance 2788.626274,
# day 2803: buy 1 unit at price 665.710022, total balance 2122.916252
# day 2805, sell 1 unit at price 673.469971, investment -4.038134 %, total balance 2796.386222,
# day 2806: buy 1 unit at price 680.260010, total balance 2116.126213
# day 2808, sell 1 unit at price 708.489990, investment 15.900803 %, total balance 2824.616203,
# day 2809: buy 1 unit at price 711.200012, total balance 2113.416191
# day 2811: buy 1 unit at price 711.919983, total balance 1401.496208
# day 2812: buy 1 unit at price 730.909973, total balance 670.586235
# day 2817, sell 1 unit at price 752.919983, investment 13.777104 %, total balance 1423.506217,
# day 2818, sell 1 unit at price 753.869995, investment 12.355251 %, total balance 2177.376213,
# day 2820: buy 1 unit at price 736.270020, total balance 1441.106193
# day 2822, sell 1 unit at price 744.489990, investment 8.875403 %, total balance 2185.596183,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()

# %%
import pickle
with open('6evolution-strategy-agent.pkl', 'wb') as fopen:
    pickle.dump(agent, fopen)

# with open('my-agent.pkl', 'rb') as fopen:
#     agent = pickle.load(fopen)
